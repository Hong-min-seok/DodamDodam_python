# %% [markdown]
# # 식물 정보 크롤링

# %% [markdown]
# # 몽고DB 연동

# %%
pip install pymongo
# Out:
# ...
#   Using cached pymongo-3.11.0-cp38-cp38-win_amd64.whl (382 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
host = 'localhost'
port = 27017
connection =  pymongo.MongoClient(host, port)

print(connection)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = connection.pytest

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'pytest')

# %%
print(dir(db))
# Out:
# ['_BaseObject__codec_options', '_BaseObject__read_concern', '_BaseObject__read_preference', '_BaseObject__write_concern', '_Database__client', '_Database__incoming_copying_manipulators', '_Database__incoming_manipulators', '_Database__name', '_Database__outgoing_copying_manipulators', '_Database__outgoing_manipulators', '__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_apply_incoming_copying_manipulators', '_apply_incoming_manipulators', '_command', '_create_or_update_user', '_current_op', '_default_role', '_fix_incoming', '_fix_outgoing', '_list_collections', '_read_preference_for', '_retryable_read_command', '_write_concern_fo
# ...

# %%
print(db.name)
# Out:
# pytest

# %%
test_collection = db.test_collection

# %%
test_collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'pytest'), 'test_collection')

# %%
post = {"author" : "Mike", "text" : "My first blog post!", "tags" : ["mongodb", "python", "pymongo"]}
test_collection.insert_one(post)

# %% [markdown]
# # 몽고DB에 꽃 데이터 넣기

# %%
import urllib.request
import urllib.parse #url을 인코딩하기 위해 불러오는 모듈
from bs4 import BeautifulSoup
import pymongo
import time

host = 'localhost'
port = 27017
connection =  pymongo.MongoClient(host, port)

print(connection)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
apikey = 'wCYGNNvDV0KSmH3pHZTf9ippvBPBGF64goZpMTpkFEwVp4qfSwx0Wn24e2RcrWHEpaBQGpfL9GapLfLlaryGeg%3D%3D'

for i in range(1, 366):
    api = 'http://apis.data.go.kr/1390804/NihhsTodayFlowerInfo/selectTodayFlowerView?serviceKey={key}&pageNo=1&numOfRows=10&dataNo={num}'
    url = api.format(key = apikey, num = i)
    
    data = urllib.request.urlopen(url).read()
    text = data.decode("UTF-8")
    
    soup = BeautifulSoup(text, 'html.parser')
    
    init = soup.select('fcsnt')[0].string
    f_name = soup.select('flowNm')[0].string
    f_sciname = soup.select('fSctNm')[0].string
    f_lang = soup.select('flowLang')[0].string
    f_grow = soup.select('fGrow')[0].string
    f_use = soup.select('fUse')[0].string
    f_img = soup.select('imgUrl1')[0].string
    
    document = {
        "init" : init,
        "f_name" : f_name,
        "f_sciname" : f_sciname,
        "f_lang" : f_lang,
        "f_grow" : f_grow,
        "f_use" : f_use,
        "f_img" : f_img
    }
    
    db = connection.dodam
    dictionary = db.dictionary
    dictionary.insert_one(document)
    time.sleep(1)
    print(i, f_name, 'is inserted!')
# Out:
# 1 향나무 is inserted!
# 2 나도풍란 is inserted!
# 3 군자란 is inserted!
# 4 삼나무 is inserted!
# 5 수선화 is inserted!
# 6 파키라 is inserted!
# 7 스토크 is inserted!
# 8 아나나스 is inserted!
# 9 아마릴리스 is inserted!
# 10 우묵사스레피 is inserted!
# 11 앵초 is inserted!
# 12 브리세아 is inserted!
# 13 치자나무 is inserted!
# 14 카틀레야 is inserted!
# 15 온시디움 is inserted!
# 16 크로커스  is inserted!
# 17 벤자민고무나무 is inserted!
# 18 팔손이 is inserted!
# 19 아프리칸 바이올렛 is inserted!
# 20 우단일엽  is inserted!
# 21 파초 is inserted!
# 22 호랑가시나무 is inserted!
# 23 사스레피나무  is inserted!
# 24 굴거리나무 is inserted!
# 25 산호수  is inserted!
# 26 꽝꽝나무 is inserted!
# 27 구상나무 is inserted!
# 28 프리뮬러 is inserted!
# 29 괭이눈  is inserted!
# 30 칼세올라리아 is inserted!
# 31 네펜데스 is inserted!
# 32 남천 is inserted!
# 33 냉이 is inserted!
# 34 동백나무 is inserted!
# 35 코르딜리네 is inserted!
# 36 디펜바키아 is inserted!
# 37 레몬 is inserted!
# 38 무스카리 is inserted!
# 39 산자고 is inserted!
# 40 스노우드롭 is inserted!
# 41 스위트피 is inserted!
# 42 복수초 is inserted!
# 43 산거울 is inserted!
# ...

# %%
db = connection.dodam
dictionary = db.dictionary
dictionary.insert_one(document)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'dodam'), 'dictionary')

# %% [markdown]
# # Atlas에 식물 데이터 넣기

# %%
pip install pymongo

# %%
pip install dnspython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install motor
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request
import urllib.parse #url을 인코딩하기 위해 불러오는 모듈
from bs4 import BeautifulSoup
import pymongo
import time
import dns
import pprint
import motor



url_path = "mongodb+srv://dodamdodam:dodamdodam@cluster0.u4wd4.mongodb.net/dodamdodam?retryWrites=true&w=majority"
client = pymongo.MongoClient(url_path)

db = client['dodamdodam']
dictionary = db['dictionary']

print(db)
print(dictionary)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.u4wd4.mongodb.net:27017', 'cluster0-shard-00-00.u4wd4.mongodb.net:27017', 'cluster0-shard-00-01.u4wd4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-97t290-shard-0', ssl=True), 'dodamdodam')
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.u4wd4.mongodb.net:27017', 'cluster0-shard-00-00.u4wd4.mongodb.net:27017', 'cluster0-shard-00-01.u4wd4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-97t290-shard-0', ssl=True), 'dodamdodam'), 'dictionary')

# %%
apikey = 'wCYGNNvDV0KSmH3pHZTf9ippvBPBGF64goZpMTpkFEwVp4qfSwx0Wn24e2RcrWHEpaBQGpfL9GapLfLlaryGeg%3D%3D'

for i in range(1, 366):
    api = 'http://apis.data.go.kr/1390804/NihhsTodayFlowerInfo/selectTodayFlowerView?serviceKey={key}&pageNo=1&numOfRows=10&dataNo={num}'
    url = api.format(key = apikey, num = i)
    
    data = urllib.request.urlopen(url).read()
    text = data.decode("UTF-8")
    
    soup = BeautifulSoup(text, 'html.parser')
    
    init = soup.select('fcsnt')[0].string
    f_name = soup.select('flowNm')[0].string
    f_sciname = soup.select('fSctNm')[0].string
    f_lang = soup.select('flowLang')[0].string
    f_grow = soup.select('fGrow')[0].string
    f_use = soup.select('fUse')[0].string
    f_img = soup.select('imgUrl1')[0].string
    
    document = {
        "init" : init,
        "f_name" : f_name,
        "f_sciname" : f_sciname,
        "f_lang" : f_lang,
        "f_grow" : f_grow,
        "f_use" : f_use,
        "f_img" : f_img,
        "f_water" : "-",
        "f_sun" : "-",
        "f_hum" : "-"
    }
    

    dictionary.insert_one(document)
    time.sleep(1)
    print(i, f_name, 'is inserted!')
# Out:
# 1 향나무 is inserted!
# 2 나도풍란 is inserted!
# 3 군자란 is inserted!
# 4 삼나무 is inserted!
# 5 수선화 is inserted!
# 6 파키라 is inserted!
# 7 스토크 is inserted!
# 8 아나나스 is inserted!
# 9 아마릴리스 is inserted!
# 10 우묵사스레피 is inserted!
# 11 앵초 is inserted!
# 12 브리세아 is inserted!
# 13 치자나무 is inserted!
# 14 카틀레야 is inserted!
# 15 온시디움 is inserted!
# 16 크로커스  is inserted!
# 17 벤자민고무나무 is inserted!
# 18 팔손이 is inserted!
# 19 아프리칸 바이올렛 is inserted!
# 20 우단일엽  is inserted!
# 21 파초 is inserted!
# 22 호랑가시나무 is inserted!
# 23 사스레피나무  is inserted!
# 24 굴거리나무 is inserted!
# 25 산호수  is inserted!
# 26 꽝꽝나무 is inserted!
# 27 구상나무 is inserted!
# 28 프리뮬러 is inserted!
# 29 괭이눈  is inserted!
# 30 칼세올라리아 is inserted!
# 31 네펜데스 is inserted!
# 32 남천 is inserted!
# 33 냉이 is inserted!
# 34 동백나무 is inserted!
# 35 코르딜리네 is inserted!
# 36 디펜바키아 is inserted!
# 37 레몬 is inserted!
# 38 무스카리 is inserted!
# 39 산자고 is inserted!
# 40 스노우드롭 is inserted!
# 41 스위트피 is inserted!
# 42 복수초 is inserted!
# 43 산거울 is inserted!
# ...

# %%
## 초성 자르기

CHOSUNG_LIST = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

JUNGSUNG_LIST = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']

JONGSUNG_LIST = [' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

def korean_to_be_englished(korean_word):
    r_lst = []
    for w in list(korean_word.strip()):
        ## 영어인 경우 구분해서 작성함. 
        if '가'<=w<='힣':
            ## 588개 마다 초성이 바뀜. 
            ch1 = (ord(w) - ord('가'))//588
            ## 중성은 총 28가지 종류
            ch2 = ((ord(w) - ord('가')) - (588*ch1)) // 28
            ch3 = (ord(w) - ord('가')) - (588*ch1) - 28*ch2
            r_lst.append([CHOSUNG_LIST[ch1], JUNGSUNG_LIST[ch2], JONGSUNG_LIST[ch3]])
        else:
            r_lst.append([w])
    return r_lst

# %%
## fleap 데이터


url = 'https://fuleaf.com/plants'

data = urllib.request.urlopen(url).read()
text = data.decode("UTF-8")

soup = BeautifulSoup(text, 'html.parser')



main = soup.select('.plants__list-item')

for tag in main:
    
    id = tag.a.attrs['href'].split('/')[3]
    url = 'https://fuleaf.com/plants/detail/' + id
    data = urllib.request.urlopen(url).read()
    text = data.decode("UTF-8")

    soup = BeautifulSoup(text, 'html.parser')
    
    f_name = soup.select_one('div.simpleinfo-title > h2').string
    f_grow =soup.select_one('div.simpleinfo-title > h3').string 
    f_img = soup.select('div.swiper-slide > img')[0].attrs['src']

    items = soup.select('li.table-item')

    f_water = '<strong>' + items[0].h1.string + '</strong><br>' + items[0].h2.string
    f_sun = '<strong>' + items[1].h1.string + '</strong><br>' + items[1].h2.string
    f_hum = '<strong>' + items[2].h1.string + '</strong><br>' + items[2].h2.string
    f_sciname = items[3].h2.string

    init = korean_to_be_englished(f_name)[0][0]
    
    document = {
        "init" : init,
        "f_name" : f_name,
        "f_sciname" : f_sciname,
        "f_lang" : '-',
        "f_grow" : f_grow,
        "f_use" : '-',
        "f_img" : f_img,
        "f_water" : f_water,
        "f_sun" : f_sun,
        "f_hum" : f_hum
    }
    
    
    dictionary.insert_one(document)
    time.sleep(1)
    print(f_name, 'is inserted!')
# Out:
# 헤데라 (아이비) is inserted!
# 몬스테라 델리시오사 is inserted!
# 알로에 베라 is inserted!
# 스투키 is inserted!
# 필로덴드론 셀로움 is inserted!
# 바질 is inserted!
# 싱고니움 is inserted!
# 무스카리 is inserted!
# 보스톤 고사리 is inserted!
# 파키라 is inserted!
# 인도 고무나무 is inserted!
# 펫츠 헤데라 is inserted!
# 염좌 is inserted!
# 홍콩 야자 (쉐프렐라 홍콩) is inserted!
# 스파티필름 is inserted!
# 몬스테라 아단소니 is inserted!
# 칼라데아 세토사 is inserted!
# 팔손이 나무 is inserted!
# 아레카야자 is inserted!
# 브레이니아 니보사 (소코라코) is inserted!
# 히아신스 is inserted!
# 극락조화 is inserted!
# 라벤더 is inserted!
# 안스리움 안드레아눔 is inserted!
# 루카덴드론 is inserted!
# 수염 틸란드시아 is inserted!
# 필로덴드론 콩고 is inserted!
# 여인초 is inserted!
# 아가베 아테누아타 is inserted!
# 원숭이꼬리 선인장 is inserted!
# 크루시아 is inserted!
# 멜라니 고무나무 is inserted!
# 금전수 (돈나무) is inserted!
# 테이블 야자 is inserted!
# 관음죽 is inserted!
# 스킨답서스 is inserted!
# 호야 콤팩타 (리본호야) is inserted!
# 초코리프 is inserted!
# 하월시아 옵투사 is inserted!
# 프리지아 is inserted!
# 다바나 고사리 is inserted!
# 베고니아 is inserted!
# 디시디아 화이트 is inserted!
# 호주매화 (마누카) is inserted!
# ...
